# %%
import pandas as pd 
import seaborn as sns

# %%
df = pd.read_csv('titanic.csv')

# %%
# entendendo a estrutura do dataset

# %%
df.shape
# Out:
# (891, 12)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull().mean().round(2) * 100
# Out:
# PassengerId     0.0
# Survived        0.0
# Pclass          0.0
# Name            0.0
# Sex             0.0
# Age            20.0
# SibSp           0.0
# Parch           0.0
# Ticket          0.0
# Fare            0.0
# Cabin          77.0
# Embarked        0.0
# dtype: float64

# %%
df = df.fillna('Nao identificado')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare             Cabin Embarked
# 0      0         A/5 21171   7.2500  Nao identificado        S
# 1      0          PC 17599  71.2833               C85        C
# 2      0  STON/O2. 3101282   7.9250  Nao identificado        S
# 3      0            113803  53.1000              C123        S
# 4      0            373450   8.0500  Nao identificado        S

# %%
df.drop(columns=['Name'], inplace=True)

# %%
df = df.rename(columns={'PassengerId':'Id_passageiro', 'Survived':'Sobrevivente', 'Pclass':'Classe', 'Sex':'Sexo', 'Age':'Idade',
                   'SibSp':'Irmaos_conjunges', 'Parch':'Pais_Filhos', 'Ticket':'Bilhete', 'Fare':'Custo_Bilhete', 'Cabin':'Cabine','Embarked':'Porto_embarque'})

# %%
df.head()
# Out:
#    Id_passageiro  Sobrevivente  Classe    Sexo Idade  Irmaos_conjunges  \
# 0              1             0       3    male  22.0                 1
# 1              2             1       1  female  38.0                 1
# 2              3             1       3  female  26.0                 0
# 3              4             1       1  female  35.0                 1
# 4              5             0       3    male  35.0                 0
#
#    Pais_Filhos           Bilhete  Custo_Bilhete            Cabine  \
# 0            0         A/5 21171         7.2500  Nao identificado
# 1            0          PC 17599        71.2833               C85
# 2            0  STON/O2. 3101282         7.9250  Nao identificado
# 3            0            113803        53.1000              C123
# 4            0            373450         8.0500  Nao identificado
#
#   Porto_embarque
# 0              S
# 1              C
# 2              S
# 3              S
# 4              S

# %%
df['Sexo'] = df['Sexo'].replace({'male':'Masculino', 'female':'Feminino'})

# %%
df['Custo_Bilhete'] = df['Custo_Bilhete'].round(2)

# %%
map_sexo = {'Masculino':1, 'Feminino':2}

# %%
df['Sexo (Nominal)'] = df['Sexo'].map(map_sexo)

# %%
map_porto = {'C':1, 'Q':2, 'S':3, 'Nao identificado':4}

# %%
df['Porto_embarque (Ordinal)'] = df['Porto_embarque'].map(map_porto)

# %%
df.head(30)
# Out:
#     Id_passageiro  Sobrevivente  Classe       Sexo             Idade  \
# 0               1             0       3  Masculino              22.0
# 1               2             1       1   Feminino              38.0
# 2               3             1       3   Feminino              26.0
# 3               4             1       1   Feminino              35.0
# 4               5             0       3  Masculino              35.0
# 5               6             0       3  Masculino  Nao identificado
# 6               7             0       1  Masculino              54.0
# 7               8             0       3  Masculino               2.0
# 8               9             1       3   Feminino              27.0
# 9              10             1       2   Feminino              14.0
# 10             11             1       3   Feminino               4.0
# 11             12             1       1   Feminino              58.0
# 12             13             0       3  Masculino              20.0
# 13             14             0       3  Masculino              39.0
# 14             15             0       3   Feminino              14.0
# 15             16             1       2   Feminino              55.0
# 16             17             0       3  Masculino               2.0
# 17             18             1       2  Masculino  Nao identificado
# 18             19             0       3   Feminino              31.0
# 19             20             1       3   Feminino  Nao identificado
# 20             21             0       2  Masculino              35.0
# 21             22             1       2  Masculino              34.0
# 22             23             1       3   Feminino              15.0
# 23             24             1       1  Masculino              28.0
# 24             25             0       3   Feminino               8.0
# 25             26             1       3   Feminino              38.0
# 26             27             0       3  Masculino  Nao identificado
# 27             28             0       1  Masculino              19.0
# 28             29             1       3   Feminino  Nao identificado
# 29             30             0       3  Masculino  Nao identificado
#
#     Irmaos_conjunges  Pais_Filhos           Bilhete  Custo_Bilhete  \
# 0                  1            0         A/5 21171           7.25
# 1                  1            0          PC 17599          71.28
# 2                  0            0  STON/O2. 3101282           7.92
# 3                  1            0            113803          53.10
# 4                  0            0            373450           8.05
# 5                  0            0            330877           8.46
# 6                  0            0             17463          51.86
# 7                  3            1            349909          21.08
# 8                  0            2            347742          11.13
# 9                  1            0            237736          30.07
# 10                 1            1           PP 9549          16.70
# 11                 0            0            113783          26.55
# 12                 0            0         A/5. 2151           8.05
# 13                 1            5            347082          31.28
# 14                 0            0            350406           7.85
# 15                 0            0            248706          16.00
# 16                 4            1            382652          29.12
# 17                 0            0            244373          13.00
# 18                 1            0            345763          18.00
# 19                 0            0              2649           7.22
# 20                 0            0            239865          26.00
# 21                 0            0            248698          13.00
# 22                 0            0            330923           8.03
# 23                 0            0            113788          35.50
# 24                 3            1            349909          21.08
# 25                 1            5            347077          31.39
# 26                 0            0              2631           7.22
# 27                 3            2             19950         263.00
# 28                 0            0            330959           7.88
# 29                 0            0            349216           7.90
#
#               Cabine Porto_embarque  Sexo (Nominal)  Porto_embarque (Ordinal)
# 0   Nao identificado              S               1                         3
# 1                C85              C               2                         1
# 2   Nao identificado              S               2                         3
# 3               C123              S               2                         3
# 4   Nao identificado              S               1                         3
# 5   Nao identificado              Q               1                         2
# 6                E46              S               1                         3
# 7   Nao identificado              S               1                         3
# 8   Nao identificado              S               2                         3
# 9   Nao identificado              C               2                         1
# 10                G6              S               2                         3
# 11              C103              S               2                         3
# 12  Nao identificado              S               1                         3
# 13  Nao identificado              S               1                         3
# 14  Nao identificado              S               2                         3
# 15  Nao identificado              S               2                         3
# 16  Nao identificado              Q               1                         2
# 17  Nao identificado              S               1                         3
# 18  Nao identificado              S               2                         3
# 19  Nao identificado              C               2                         1
# 20  Nao identificado              S               1                         3
# 21               D56              S               1                         3
# 22  Nao identificado              Q               2                         2
# 23                A6              S               1                         3
# 24  Nao identificado              S               2                         3
# 25  Nao identificado              S               2                         3
# 26  Nao identificado              C               1                         1
# 27       C23 C25 C27              S               1                         3
# 28  Nao identificado              Q               2                         2
# 29  Nao identificado              S               1                         3
